# %% [markdown]
# <a href="https://colab.research.google.com/github/kajaltiwa/kajal11/blob/main/Heart_Disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

# Sample data
data = {
    'Age': [63, 67, 67, 70],
    'Sex': ['Male', 'Female', 'Male', 'Male'],
    'ChestPainType': ['Typical Angina', 'Non-Anginal Pain', 'Atypical Angina', 'Asymptomatic'],
    'RestingBP': [145, 160, 120, 140],
    'Cholesterol': [233, 286, 229, 239],
    'FastingBS': [1, 0, 0, 0],
    'RestingECG': ['Normal', 'Normal', 'Normal', 'Normal'],
    'MaxHR': [150, 108, 129, 124],
    'ExerciseAngina': ['No', 'Yes', 'Yes', 'Yes'],
    'Oldpeak': [2.3, 1.5, 2.6, 3.1],
    'Slope': ['Up', 'Flat', 'Up', 'Flat'],
    'CA': [0, 0, 0, 0],
    'Thal': ['Normal', 'Normal', 'Normal', 'Normal'],
    'HeartDisease': [1, 1, 1, 1]
}

# Convert data to DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV file
df.to_csv('/content/heart_disease_data.csv', index=False)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
df.head()
# Out:
#    Age     Sex     ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0   63    Male    Typical Angina        145          233          1
# 1   67  Female  Non-Anginal Pain        160          286          0
# 2   67    Male   Atypical Angina        120          229          0
# 3   70    Male      Asymptomatic        140          239          0
#
#   RestingECG  MaxHR ExerciseAngina  Oldpeak Slope  CA    Thal  HeartDisease
# 0     Normal    150             No      2.3    Up   0  Normal             1
# 1     Normal    108            Yes      1.5  Flat   0  Normal             1
# 2     Normal    129            Yes      2.6    Up   0  Normal             1
# 3     Normal    124            Yes      3.1  Flat   0  Normal             1

# %%
df.shape
# Out:
# (4, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of    Age     Sex     ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0   63    Male    Typical Angina        145          233          1
# 1   67  Female  Non-Anginal Pain        160          286          0
# 2   67    Male   Atypical Angina        120          229          0
# 3   70    Male      Asymptomatic        140          239          0
#
#   RestingECG  MaxHR ExerciseAngina  Oldpeak Slope  CA    Thal  HeartDisease
# 0     Normal    150             No      2.3    Up   0  Normal             1
# 1     Normal    108            Yes      1.5  Flat   0  Normal             1
# 2     Normal    129            Yes      2.6    Up   0  Normal             1
# 3     Normal    124            Yes      3.1  Flat   0  Normal             1  >

# %%
df.describe()
# Out:
#              Age  RestingBP  Cholesterol  FastingBS       MaxHR   Oldpeak  \
# count   4.000000    4.00000     4.000000       4.00    4.000000  4.000000
# mean   66.750000  141.25000   246.750000       0.25  127.750000  2.375000
# std     2.872281   16.52019    26.487418       0.50   17.327723  0.670199
# min    63.000000  120.00000   229.000000       0.00  108.000000  1.500000
# 25%    66.000000  135.00000   232.000000       0.00  120.000000  2.100000
# 50%    67.000000  142.50000   236.000000       0.00  126.500000  2.450000
# 75%    67.750000  148.75000   250.750000       0.25  134.250000  2.725000
# max    70.000000  160.00000   286.000000       1.00  150.000000  3.100000
#
#         CA  HeartDisease
# count  4.0           4.0
# mean   0.0           1.0
# std    0.0           0.0
# min    0.0           1.0
# 25%    0.0           1.0
# 50%    0.0           1.0
# 75%    0.0           1.0
# max    0.0           1.0

# %%
print(df.columns)
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'Slope', 'CA',
#        'Thal', 'HeartDisease'],
#       dtype='object')

# %%
df.rename(columns={'HeartDisease': 'target'}, inplace=True)

# %%
df['target'].value_counts()
# Out:
# target
# 1    4
# Name: count, dtype: int64

# %%
X = df.drop(columns='target',axis=1)

# %%
X
# Out:
#    Age     Sex     ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0   63    Male    Typical Angina        145          233          1
# 1   67  Female  Non-Anginal Pain        160          286          0
# 2   67    Male   Atypical Angina        120          229          0
# 3   70    Male      Asymptomatic        140          239          0
#
#   RestingECG  MaxHR ExerciseAngina  Oldpeak Slope  CA    Thal
# 0     Normal    150             No      2.3    Up   0  Normal
# 1     Normal    108            Yes      1.5  Flat   0  Normal
# 2     Normal    129            Yes      2.6    Up   0  Normal
# 3     Normal    124            Yes      3.1  Flat   0  Normal

# %%
Y = df['target']

# %%
Y
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# Name: target, dtype: int64

# %% [markdown]
# SPLITTING DATASET INTO TRAIN AND TEST

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X_test.shape, X_train.shape)
# Out:
# (1, 13) (3, 13)

# %% [markdown]
# MODEL TRAINING

# %%
model = LogisticRegression()
